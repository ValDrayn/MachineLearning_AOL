# %%
import pandas as pd
import sys
import os

# Add the path to the utils folder to the system path
if os.path.basename(os.getcwd()) == 'notebooks':
    sys.path.append('../')

from utils.functions import get_results_df, mean_df
from utils.functions import process_images
from utils.functions import plot_model_size, plot_model_params, plot_precision_recall, plot_mAP, save_plots

# Get current working directory
repo_path = os.path.dirname(os.getcwd())

# %%
print(repo_path)
# Out:
# c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak

# %%
print(f'{repo_path}/results/best/')
# Out:
# c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/

# %% [markdown]
# Ini Yolov5

# %%
# Specify the model path or the model name if it is in the models folder.
model_path = f'{repo_path}/models/yolov8n/exp4/weights/best.pt'
model = "yolov5n"

# Specify the output folder path
output_folder = f'{repo_path}/results/{model}/'

# process_images returns a dataframe containing the results
results = process_images(data_path, output_folder, highlighted_cars=True, model=model_path)
results.head(20) # # Show the results for the first 20 images

# %% [markdown]
# Ini Yolov8

# %%
# Specify the model path or the model name if it is in the models folder.
data_path = os.path.join(repo_path, 'data', 'val')
model_path = f'{repo_path}/results/best/labels'
model = "yolov8n"

# Specify the output folder path
output_folder = f'{repo_path}/results/{model}/'

# Panggil fungsi dengan argumen 'model' sebagai string biasa
results = process_images(data_path, output_folder, model=model_path) # DIUBAH: Hapus kurung kurawal {}

results.head(20) # # Show the results for the first 20 images
# Out:
# Using labels from c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/labels
# Menggunakan label langsung dari folder prediksi: c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/labels
# Processing images...
# Processed 321 images ✅
#                                            Image File  Empty Spots  \
# 0   2012-09-11_15_36_32_jpg.rf.b2b1767cafabff63784...           30
# 1   2012-09-11_15_45_57_jpg.rf.01d1052a2938ca83e8b...           30
# 2   2012-09-11_17_12_07_jpg.rf.e73a27714868ec27c08...           25
# 3   2012-09-11_17_31_01_jpg.rf.2e04e95005bf92a48a7...           24
# 4   2012-09-11_17_35_44_jpg.rf.5663fefeb1afb80585d...           25
# 5   2012-09-11_17_59_15_jpg.rf.29ca7e6dbc33db072c0...           32
# 6   2012-09-11_18_03_58_jpg.rf.b9ac8b4e0bc746f70a7...           29
# ...

# %% [markdown]
# Ini Yolov10

# %%
# Specify the model path or the model name if it is in the models folder.
data_path = os.path.join(repo_path, 'data', 'val')
model_path = f'{repo_path}/results/best/labels'
model = "yolov10n"

# Specify the output folder path
output_folder = f'{repo_path}/results/{model}/'

# Panggil fungsi dengan argumen 'model' sebagai string biasa
results = process_images(data_path, output_folder, model=model_path) # DIUBAH: Hapus kurung kurawal {}

results.head(20) # # Show the results for the first 20 images
# Out:
# Using labels from c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/labels
# Menggunakan label langsung dari folder prediksi: c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/labels
# Processing images...
# ⚠️ No detections for 2012-09-12_06_26_11_jpg.rf.7ff1217fe3f62dcfe37be6ad7fd1a334.jpg, skipping visualization.
# ⚠️ No detections for 2012-09-12_06_31_24_jpg.rf.11cca31cda632773940bb17f821a38ab.jpg, skipping visualization.
# ⚠️ No detections for 2012-09-15_18_02_28_jpg.rf.f8240b0f2696fe78f4320bea0aa1dba8.jpg, skipping visualization.
# ⚠️ No detections for 2012-09-15_18_12_29_jpg.rf.2e35a42351385b93d1b80a22401b7fd8.jpg, skipping visualization.
# ⚠️ No detections for 2012-09-16_06_22_55_jpg.rf.ee4c08bfcc20248a536d12aa09def8b7.jpg, skipping visualization.
# ...

# %% [markdown]
# Ini Yolo11

# %%
data_path = os.path.join(repo_path, 'data', 'val')
# model_path = f'{repo_path}/models/yolo11n/train/weights/best.pt'
model_path = f'{repo_path}/results/best/labels'
model = "yolo11n"

# Specify the output folder path
output_folder = f'{repo_path}/results/{model}/'

results = process_images(data_path, output_folder, model=model_path)

results.head(20)
# Out:
# Using labels from c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/labels
# Menggunakan label langsung dari folder prediksi: c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/labels
# Processing images...
# Processed 321 images ✅
#                                            Image File  Empty Spots  \
# 0   2012-09-11_15_36_32_jpg.rf.b2b1767cafabff63784...           32
# 1   2012-09-11_15_45_57_jpg.rf.01d1052a2938ca83e8b...           31
# 2   2012-09-11_17_12_07_jpg.rf.e73a27714868ec27c08...           25
# 3   2012-09-11_17_31_01_jpg.rf.2e04e95005bf92a48a7...           25
# 4   2012-09-11_17_35_44_jpg.rf.5663fefeb1afb80585d...           26
# 5   2012-09-11_17_59_15_jpg.rf.29ca7e6dbc33db072c0...           32
# 6   2012-09-11_18_03_58_jpg.rf.b9ac8b4e0bc746f70a7...           28
# ...

# %%
print(model_path)
# Out:
# c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/models/yolov8n/train2/weights/best.pt

# %% [markdown]
# Ini Yolo12

# %%
data_path = os.path.join(repo_path, 'data', 'val')
# model_path = f'{repo_path}/models/yolo11n/train/weights/best.pt'
model_path = f'{repo_path}/results/best/labels'
model = "yolo12n"

# Specify the output folder path
output_folder = f'{repo_path}/results/{model}/'

results = process_images(data_path, output_folder, model=model_path)

results.head(20)
# Out:
# Using labels from c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/labels
# Menggunakan label langsung dari folder prediksi: c:\Users\Evaldo Raynardi\OneDrive\Desktop\Kuilah\Semester 4\Machine Learning\testing\YOLO-Parking-Spot-Rombak/results/best/labels
# Processing images...
# Processed 321 images ✅
#                                            Image File  Empty Spots  \
# 0   2012-09-11_15_36_32_jpg.rf.b2b1767cafabff63784...           32
# 1   2012-09-11_15_45_57_jpg.rf.01d1052a2938ca83e8b...           30
# 2   2012-09-11_17_12_07_jpg.rf.e73a27714868ec27c08...           26
# 3   2012-09-11_17_31_01_jpg.rf.2e04e95005bf92a48a7...           24
# 4   2012-09-11_17_35_44_jpg.rf.5663fefeb1afb80585d...           25
# 5   2012-09-11_17_59_15_jpg.rf.29ca7e6dbc33db072c0...           32
# 6   2012-09-11_18_03_58_jpg.rf.b9ac8b4e0bc746f70a7...           29
# ...
